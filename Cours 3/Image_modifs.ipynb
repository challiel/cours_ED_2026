# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread('/home/leo-challier/Documents/Gricad/Photo_profil.jpg')

# %%
plt.imshow(im)

# %%
cv2.cvtColor(im, cv2.COLOR_BGR2LAB)
# Out:
# array([[[122, 110, 155],
#         [122, 110, 155],
#         [121, 110, 154],
#         ...,
#         [ 94, 124, 153],
#         [ 95, 124, 153],
#         [ 98, 124, 153]],
#
#        [[120, 110, 155],
#         [121, 110, 155],
#         [123, 110, 154],
#         ...,
#         [ 97, 124, 153],
#         [ 97, 124, 153],
#         [ 95, 124, 153]],
#
#        [[119, 109, 155],
#         [121, 110, 155],
#         [124, 110, 154],
#         ...,
#         [ 99, 124, 153],
#         [ 98, 124, 153],
#         [ 95, 124, 153]],
#
#        ...,
#
#        [[ 15, 130, 123],
#         [ 16, 130, 123],
#         [ 15, 130, 123],
#         ...,
#         [ 49, 126, 126],
#         [ 47, 126, 126],
#         [ 47, 126, 126]],
#
#        [[ 15, 130, 123],
#         [ 18, 130, 122],
#         [ 23, 130, 123],
#         ...,
#         [ 42, 127, 126],
#         [ 43, 127, 126],
#         [ 46, 126, 127]],
#
#        [[ 16, 130, 123],
#         [ 23, 130, 123],
#         [ 29, 131, 122],
# ...

# %%
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2LAB)[:,:,2])
