# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# %%
iris = load_iris(as_frame = True)

# %%
df = pd.DataFrame(iris['data'])
df['target'] = iris['target']

# %%
pca = PCA(n_components=3)

# %%
X_transformed = pca.fit_transform(df.iloc[:,:4])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(X_transformed[:,0],X_transformed[:,1],c=df['target'])
ax.legend(scatter.legend_elements()[0],
    iris.target_names.tolist(),
    loc="upper right",
    title="Classes",)
ax.set(title="First two PCA dimensions",
    xlabel="1st Eigenvector",
    ylabel="2nd Eigenvector")
# Out:
# [Text(0.5, 1.0, 'First two PCA dimensions'),
#  Text(0.5, 0, '1st Eigenvector'),
#  Text(0, 0.5, '2nd Eigenvector')]

# %%
df['target'].unique().tolist()
# Out:
# [0, 1, 2]
